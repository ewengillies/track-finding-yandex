# %%
get_ipython().magic(u'run visualizations.ipynb')
import sys
import hits
from memory_profiler import memory_usage
from collections import Counter
sys.path.insert(0, '../modules')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Get the data

# %%
data_file = "/vols/comet00/users/elg112/ICEDUST"\
            "/local_storage/SimDetectorResponse_tree"\
            "/new_sdetresp_analy/test_signal_sample_analysis.root"

# %%
reload(hits)
from hits import CyDetHits
ice_cydet = CyDetHits(path=data_file, 
                     tree="COMETEventsSummary", 
                     prefix="CDCHit.f",
                     hit_type_name="Track.fTrackID",
                     signal_coding=[1],
                     use_evt_idx=True)
# Out:
# I know about the changes!!

# %%
ice_cydet.print_branches()
# Out:
# Branches available are:
# CDCHit.fTrack.fTrackID
# CDCHit.fEventNumber
# CDCHit.fhits_index
# CDCHit.fevent_index
# CDCHit.fvol_id
# CDCHit.fCharge
# CDCHit.fMCPos.fE
# CDCHit.fTrigTime

# %% [markdown]
# # Visualise the data

# %%
for event in np.unique(ice_cydet.hits_to_events)[:10]:
    plot_output(ice_cydet.get_hit_types(event), ice_cydet.geom)
    show()
