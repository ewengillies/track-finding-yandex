# %%
import sys
sys.path.insert(0, '../../modules')
# %pylab inline
# %run ../visualizations.ipynb
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib

# %%
from tracking import HoughSpace
from scipy import sparse
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.ticker as mtick
from hits import CyDetHits, CTHHits, CDCHits
from cylinder import CDC

# %% [markdown]
# # Import RECBE Wiring

# %%
import root_numpy
from pprint import pprint
from pandas import DataFrame

# %%
recbe_wiring_file = "/home/elg112/development/ICEDUST/track_finding_standalone/"+\
                    "track_finding_yandex/data/chanmap_20160814.root"
recbe_positions = root_numpy.root2array(recbe_wiring_file, 
                                        selection="isSenseWire == 1 && LayerID > 0 && LayerID < 19")
recbe_positions["LayerID"] = recbe_positions["LayerID"] - 1

# %%
root_numpy.list_branches(recbe_wiring_file)
# Out:
# ['LayerLength',
#  'layer',
#  'wire',
#  'xhv',
#  'yhv',
#  'x0',
#  'y0',
#  'xro',
#  'yro',
#  'LayerID',
#  'isSenseWire',
#  'CellID',
#  'BoardID',
#  'BrdLayID',
#  'BrdLocID',
#  'ChanID']

# %%
root_numpy.list_trees(recbe_wiring_file)
# Out:
# ['t']

# %%
print max(recbe_positions["LayerID"])
# Out:
# 17

# %%
rbdf = DataFrame(recbe_positions).sort_values(by=["LayerID", "CellID"])
rbdf
# Out:
#       LayerLength  layer  wire         xhv         yhv          x0  \
# 0     1481.688151      2     1  521.948109  -92.033534  528.333031
# 1     1481.688151      2     3  524.605364  -75.426864  529.399690
# 2     1481.688151      2     5  526.734386  -58.744246  529.933288
# 3     1481.688151      2     7  528.333031  -42.002477  529.933288
# 4     1481.688151      2     9  529.399690  -25.218415  529.399690
# 5     1481.688151      2    11  529.933288   -8.408961  528.333031
# 6     1481.688151      2    13  529.933288    8.408961  526.734386
# 7     1481.688151      2    15  529.399690   25.218415  524.605364
# 8     1481.688151      2    17  528.333031   42.002477  521.948109
# 9     1481.688151      2    19  526.734386   58.744246  518.765296
# 10    1481.688151      2    21  524.605364   75.426864  515.060131
# 11    1481.688151      2    23  521.948109   92.033534  510.836344
# 12    1481.688151      2    25  518.765296  108.547534  506.098188
# 13    1481.688151      2    27  515.060131  124.952236  500.850434
# 14    1481.688151      2    29  510.836344  141.231121  495.098366
# 15    1481.688151      2    31  506.098188  157.367799  488.847776
# 16    1481.688151      2    33  500.850434  173.346021  482.104958
# 17    1481.688151      2    35  495.098366  189.149697  474.876700
# 18    1481.688151      2    37  488.847776  204.762917  467.170283
# 19    1481.688151      2    39  482.104958  220.169957  458.993464
# 20    1481.688151      2    41  474.876700  235.355305  450.354478
# 21    1481.688151      2    43  467.170283  250.303670  441.262023
# 22    1481.688151      2    45  458.993464  265.000000  431.725255
# 23    1481.688151      2    47  450.354478  279.429498  421.753775
# 24    1481.688151      2    49  441.262023  293.577634  411.357626
# 25    1481.688151      2    51  431.725255  307.430162  400.547274
# 26    1481.688151      2    53  421.753775  320.973134  389.333606
# 27    1481.688151      2    55  411.357626  334.192914  377.727911
# 28    1481.688151      2    57  400.547274  347.076189  365.741876
# 29    1481.688151      2    59  389.333606  359.609988  353.387570
# ...           ...    ...   ...         ...         ...         ...
# 4452  1577.610029     36   540  710.735271 -371.563420  681.613940
# 4453  1577.610029     36   542  718.360832 -356.597414  690.315106
# 4454  1577.610029     36   544  725.671296 -341.474992  698.713477
# 4455  1577.610029     36   546  732.663457 -326.202788  706.805369
# 4455 -378.985713  677.150996 -429.733090       17            1     273
# 4456 -364.100381  686.002137 -415.457662       17            1     274
# 4457 -349.055342  694.552374 -401.000000       17            1     275
# 4458 -333.857195  702.797957 -386.366447       17            1     276
# 4459 -318.512608  710.735271 -371.563420       17            1     277
# 4460 -303.028311  718.360832 -356.597414       17            1     278
# 4461 -287.411096  725.671296 -341.474992       17            1     279
# 4462 -271.667812  732.663457 -326.202788       17            1     280
# 4463 -255.805366  739.334248 -310.787500       17            1     281
# 4464 -239.830715  745.680742 -295.235891       17            1     282
# 4465 -223.750867  751.700156 -279.554782       17            1     283
# 4466 -207.572874  757.389849 -263.751051       17            1     284
# 4467 -191.303833  762.747326 -247.831629       17            1     285
# 4468 -174.950880  767.770237 -231.803501       17            1     286
# 4469 -158.521187  772.456379 -215.673696       17            1     287
# 4470 -142.021962  776.803695 -199.449290       17            1     288
# 4471 -125.460441  780.810280 -183.137398       17            1     289
# 4472 -108.843889  784.474376 -166.745176       17            1     290
# 4473  -92.179595  787.794375 -150.279814       17            1     291
# 4474  -75.474867  790.768822 -133.748535       17            1     292
# 4475  -58.737034  793.396411 -117.158589       17            1     293
# 4476  -41.973437  795.675990 -100.517253       17            1     294
# 4477  -25.191429  797.606560  -83.831828       17            1     295
# 4478   -8.398371  799.187273  -67.109630       17            1     296
# 4479    8.398371  800.417436  -50.357997       17            1     297
# 4480   25.191429  801.296510  -33.584274       17            1     298
# 4481   41.973437  801.824108  -16.795821       17            1     299
#
#       BoardID  BrdLayID  BrdLocID  ChanID
# 0           0         0         0       2
# 1           0         0         0       1
# 2           0         0         0       3
# 3           0         0         0      14
# 4           0         0         0      21
# 5           0         0         0      23
# 6           0         0         0      24
# 7           0         0         0      26
# 8           0         0         0      29
# 9           0         0         0      41
# 10          0         0         0      45
# 11          0         0         0      47
# 12          1         0         1       0
# 13          1         0         1       1
# 14          1         0         1       3
# 15          1         0         1       9
# 16          1         0         1      21
# 17          1         0         1      23
# 18          1         0         1      22
# 19          1         0         1      24
# 20          1         0         1      25
# 21          1         0         1      37
# 22          1         0         1      43
# 23          1         0         1      45
# 24          1         0         1      47
# 25          2         0         2       3
# 26          2         0         2       5
# 27          2         0         2       7
# 28          2         0         2      18
# 29          2         0         2      23
# ...       ...       ...       ...     ...
# 4452      102         5        16       4
# 4453      102         5        16      13
# 4454      102         5        16      14
# 4455      102         5        16      18
# 4456      102         5        16      22
# 4457      102         5        16      25
# 4458      102         5        16      24
# 4459      102         5        16      27
# 4460      102         5        16      32
# 4461      102         5        16      38
# 4462      102         5        16      44
# 4463      102         5        16      43
# 4464      102         5        16      45
# 4465      102         5        16      47
# 4466      103         5        17       1
# 4467      103         5        17       3
# 4468      103         5        17       0
# 4469      103         5        17       2
# 4470      103         5        17       8
# 4471      103         5        17      14
# 4472      103         5        17      22
# 4473      103         5        17      19
# 4474      103         5        17      23
# 4475      103         5        17      24
# 4476      103         5        17      30
# 4477      103         5        17      36
# 4478      103         5        17      42
# 4479      103         5        17      43
# 4480      103         5        17      45
# 4481      103         5        17      47
#
# [4482 rows x 16 columns]

# %% [markdown]
# ## Check Correspondence

# %%
cydet_geom = CDC(projection=0.0)

# %%
print "[",
counter = 0
for value in cydet_geom.phi0_by_layer - np.pi:
    print "{0:08f}".format(value)+",",
    counter += 1
    if counter % 2 == 0:
        print "\n ",
print "]"
# Out:
# [ 0.015867, 0.015400,
#   0.000000, 0.014543,
#   0.000000, 0.000001,
#   0.013427, 0.000000,
#   0.012771, 0.000000,
#   0.012176, 0.000000,
#   0.011636, 0.000001,
#   0.000000, 0.000000,
#   0.010686, 0.000000,
#   ]

# %%
layer_id = 1
#recbe_wires = recbe_positions[np.where(recbe_positions["LayerID"] == layer_id+1)]

# %%
x_pos_cdc, y_pos_cdc = cydet_geom.get_points_xs_and_ys()

# %%
all_colour = np.linspace(0,1,104)
np.random.shuffle(all_colour)

# %%
import matplotlib.cm as cm
from scipy.spatial import ConvexHull

# %%
print np.ones((200,4,2))[0]
# Out:
# [[ 1.  1.]
#  [ 1.  1.]
#  [ 1.  1.]
#  [ 1.  1.]]

# %%
dphi_point = cydet_geom.dphi_by_layer[cydet_geom.point_layers]
drad_point = np.ones(4482) * 1.6
cy_rho, cy_phi = cydet_geom.get_points_rhos_and_phis()
bound_box = np.zeros((cydet_geom.n_points, 9, 2))
enum = 0
for d_phi in [dphi_point, -dphi_point, 0]:
    for d_rho in [drad_point, -drad_point, 0]:
        bound_box[:,enum,0] = cy_rho + d_rho/2.
        bound_box[:,enum,1] = cy_phi + d_phi/2.
        enum += 1

# %%
bound_box_cart = np.zeros_like(bound_box)
bound_box_cart[:,:,0] = bound_box[:,:,0] * np.cos(bound_box[:,:,1])
bound_box_cart[:,:,1] = bound_box[:,:,0] * np.sin(bound_box[:,:,1])
print bound_box[10]
print np.vstack(bound_box_cart[10:20]).shape
# Out:
# [[ 53.8          3.49065887]
#  [ 52.2          3.49065887]
#  [ 53.           3.49065887]
#  [ 53.8          3.45892562]
#  [ 52.2          3.45892562]
#  [ 53.           3.45892562]
#  [ 53.8          3.47479224]
#  [ 52.2          3.47479224]
#  [ 53.           3.47479224]]
# (90, 2)

# %%
recbe_layers = recbe_positions["LayerID"]
recbe_cells = recbe_positions["CellID"]
recbe_flat = cydet_geom.point_lookup[recbe_layers,recbe_cells]
board_id_flat = recbe_positions["BoardID"]
board_neighs = board_id_flat[cydet_geom.shift_wires(-1)]
board_neighs = np.vstack([board_id_flat[cydet_geom.shift_wires(-1)],
                          board_id_flat[cydet_geom.shift_wires(0)],
                          board_id_flat[cydet_geom.shift_wires(1)]]).T
lim_point_lr = np.vstack([board_neighs[:,0] == board_neighs[:,1],
                          board_neighs[:,2] == board_neighs[:,1],
                          board_]).T

# %%
plot_output(np.zeros(cydet_geom.n_points), cydet_geom, figsize=(10,10))
plot_colors = iter(cm.nipy_spectral(all_colour))
for board_id in range(10):
#plt.scatter(x_pos_recbe, y_pos_recbe, s=4, transform=gca().transData._b, color="blue")
    recbe_wires = recbe_positions[np.where( (recbe_positions["BoardID"] == board_id))]
    recbe_layers = recbe_wires["LayerID"]
    recbe_cells = recbe_wires["CellID"]
    board_point_ids = cydet_geom.point_lookup[recbe_layers,recbe_cells]
    points = np.vstack([x_pos_cdc[board_point_ids], 
                        y_pos_cdc[board_point_ids]]).T
    #points = np.vstack(bound_box_cart[board_point_ids])
    c_hull = ConvexHull(points)
    plot_verts = np.append(c_hull.vertices, c_hull.vertices[0])
    plt_col = next(plot_colors)
    plt.plot(points[plot_verts,0], 
             points[plot_verts,1], 
             color=plt_col, 
             lw=2,transform=gca().transData._b)
    plt.scatter(points[:,0], points[:,1], s=0.5, 
                color=plt_col,
                alpha=0.5,
                transform=gca().transData._b)
